# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
movies = pd.read_csv('/kaggle/input/the-movies-dataset/movies_metadata.csv', low_memory=False)
movies = movies[['title', 'overview']].dropna()

# %%
tfidf = TfidfVectorizer(stop_words='english')
tfidf_matrix = tfidf.fit_transform(movies['overview'])

# %%
cosine_sim = cosine_similarity(tfidf_matrix, tfidf_matrix)

# %%
def recommend(title):
    idx = movies[movies['title'] == title].index[0]
    scores = list(enumerate(cosine_sim[idx]))
    scores = sorted(scores, key=lambda x: x[1], reverse=True)[1:6]
    return movies.iloc[[i[0] for i in scores]]['title']

# %%
print(recommend("Avatar"))
# Out:
# 14524          The Childhood of Maxim Gorky
# 31762          Joan the Maid 2: The Prisons
# 14606                              Piter FM
# 43546                   The Best Movie 3-DE
# 13321    Why We Fight: War Comes to America
# Name: title, dtype: object

# %%
movie_name = "The Dark Knight"
recommended = recommend(movie_name)

print("Movies similar to:", movie_name)
for m in recommended:
    print("-", m)
# Out:
# Movies similar to: The Dark Knight
# - Foreign Student
# - See You in Montevideo
# - Everybody's All-American
# - Devil's Doorway
# - Semi-Tough
